# %%
# code used to ensure that scripps data imports works properly
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
# SCRIPPS packages
from packages import MotionAnalyzer
from packages import SleepAnalyzer
from packages import IBIAnalyzer

# %% [markdown]
# ## Sleep Package and Methods

# %%
sleep = SleepAnalyzer
df = sleep.sleep_dataset_reader('datasets/scripps1_sleep.csv')
df.head()
# Out:
#          Date  Bedtime start Unix  Bedtime end Unix Bedtime start Bedtime end  \
# 0  27.11.2018        1.543351e+09      1.543352e+09      12:35:53    12:49:53
# 1  27.11.2018        1.543368e+09      1.543369e+09      17:17:55    17:37:55
# 2  28.11.2018        1.543386e+09      1.543419e+09      22:16:15     7:32:15
# 3  28.11.2018        1.543438e+09      1.543440e+09      12:52:26    13:12:26
# 4  29.11.2018        1.543463e+09      1.543464e+09      19:44:43    19:54:43
#
#    TimeZone Debug info Battery consumption  Is longest  Time in bed  ...  \
# 0      -8.0        NaN                 NaN         1.0         14.0  ...
# 1      -8.0        NaN                 NaN         1.0         20.0  ...
# 2      -8.0        NaN                1.2%         1.0        556.0  ...
# 3      -8.0        NaN                 NaN         0.0         20.0  ...
# 4      -8.0        NaN                 NaN         1.0         10.0  ...
#
# ...

# %%
sleep.corr_heatmap(sleep,df)

# %%
naps,rest = sleep.naps_and_sleep(sleep,df)

# %%
sleep.sleepduration_vs_sleepscore_plot(naps,rest,True,True)

# %%
sleep.bedtimestart_vs_sleepscore_plot(naps,rest,True,True)

# %%
sleep.sleepphases_vs_sleepscore_plot(sleep,df)

# %%
sleep.durationofsleep_vs_day_plot(df)

# %%
sleep.durationofsleep_vs_day_separated_plot(df)

# %% [markdown]
# ## IBI Package and Methods

# %%
ibi = IBIAnalyzer
df = ibi.ibi_dataset_reader('datasets/scripps1_ibi.csv')
df.head()
# Out:
#         Date      Time  Validity  Padded IBI     IBI      UTC time
# 0 2018-11-27  12:37:43         0        1312  1312.0  1.543351e+09
# 1 2018-11-27  12:37:43         1         980   980.0  1.543351e+09
# 2 2018-11-27  12:37:43         1         956   956.0  1.543351e+09
# 3 2018-11-27  12:37:43         1        1096  1096.0  1.543351e+09
# 4 2018-11-27  12:37:43         1        1172  1172.0  1.543351e+09

# %%
ibi.ibi_vs_time_plot(df, True, True, True)

# %%
ibi.valid_ibi_proportion_plot(df,True, True, False)

# %%
ibi.boxplot_style_one(df)

# %%
ibi.boxplot_style_two(df)

# %%
ibi.lineplot_of_valid_ibis(ibi,df,time='morning')

# %%
ibi.markov_chain(df)
# Out:
# next        False     True
# initial
# False    0.758826  0.241174
# True     0.046645  0.953355

# %%
ibi.poincare_plot(ibi,df)

# %%
ibi.rmssd(ibi,df)
# Out:
# 227.96896421991408

# %%
ibi.sdnn(ibi,df)
# Out:
# 220.44170879240937

# %%
ibi.nn50(ibi,df)
# Out:
# 208878

# %%
ibi.pnn50(ibi,df)
# Out:
# 0.42620943799315625
